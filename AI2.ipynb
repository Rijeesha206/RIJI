# %% [markdown]
# <a href="https://colab.research.google.com/github/Rijeesha206/RIJI/blob/main/AI2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#getting an image using web get
# !wget'https://images.unsplash.com/photo-1611003228941-98852ba62227?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8YmFieSUyMGRvZ3xlbnwwfHwwfHx8MA%3D%3D&w=1000&q=80'
# Out:
# /bin/bash: wgethttps://images.unsplash.com/photo-1611003228941-98852ba62227?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8YmFieSUyMGRvZ3xlbnwwfHwwfHx8MA%3D%3D&w=1000&q=80: No such file or directory

# %%
#importing the image module frommatplotlib libary
import matplotlib.image as mpimg #image processing library
import matplotlib.pyplot as plt #plotting library

# %%
#loading an image throgh matplotlib.image module
img=mpimg.imread('/content/photo-1611003228941-98852ba62227.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img)#3value bcz RGB)
# Out:
# [[[ 0  1  5]
#   [ 0  1  5]
#   [ 0  1  5]
#   ...
#   [ 8 11 18]
#   [ 8 11 18]
#   [ 8 11 18]]
#
#  [[ 0  1  5]
#   [ 0  1  5]
#   [ 0  1  5]
#   ...
#   [ 8 11 18]
#   [ 8 11 18]
#   [ 8 11 18]]
#
#  [[ 0  1  5]
#   [ 0  1  5]
#   [ 0  1  5]
#   ...
#   [ 8 11 18]
#   [ 8 11 18]
#   [ 8 11 18]]
#
#  ...
#
#  [[62 82 93]
#   [62 82 93]
#   [62 82 93]
#   ...
#   [11 19 30]
#   [10 18 29]
#   [10 18 29]]
#
#  [[62 82 93]
#   [62 82 93]
#   [62 82 93]
#   ...
#   [10 18 29]
#   [10 18 29]
#   [10 18 29]]
#
#  [[62 82 93]
#   [62 82 93]
#   [62 82 93]
#   ...
#   [10 18 29]
#   [10 18 29]
#   [ 9 17 28]]]

# %%
print(img)#printing the image as numpy array
# Out:
# [[[ 0  1  5]
#   [ 0  1  5]
#   [ 0  1  5]
#   ...
#   [ 8 11 18]
#   [ 8 11 18]
#   [ 8 11 18]]
#
#  [[ 0  1  5]
#   [ 0  1  5]
#   [ 0  1  5]
#   ...
#   [ 8 11 18]
#   [ 8 11 18]
#   [ 8 11 18]]
#
#  [[ 0  1  5]
#   [ 0  1  5]
#   [ 0  1  5]
#   ...
#   [ 8 11 18]
#   [ 8 11 18]
#   [ 8 11 18]]
#
#  ...
#
#  [[62 82 93]
#   [62 82 93]
#   [62 82 93]
#   ...
#   [11 19 30]
#   [10 18 29]
#   [10 18 29]]
#
#  [[62 82 93]
#   [62 82 93]
#   [62 82 93]
#   ...
#   [10 18 29]
#   [10 18 29]
#   [10 18 29]]
#
#  [[62 82 93]
#   [62 82 93]
#   [62 82 93]
#   ...
#   [10 18 29]
#   [10 18 29]
#   [ 9 17 28]]]

# %%
img_plot=plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from PIL import Image #image file formatting library

# %%
img=Image.open('/content/photo-1611003228941-98852ba62227.jpg')
img_resized=img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
#displaying the image from numpy array
img_res=mpimg.imread('/content/photo-1611003228941-98852ba62227.jpg')
img_res_plot=plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (750, 1000, 3)

# %%
#importing openCV library
import cv2#computer vision library

# %%
img=cv2.imread('/content/photo-1611003228941-98852ba62227.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (750, 1000, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape#then 2 values only
# Out:
# (750, 1000)

# %%
from google.colab.patches import cv2_imshow

# %%
#displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=1000x750 at 0x7F860C5ED870>

# %%
#saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg',grayscale_image)
# Out:
# True
